# %%
from pathlib import Path 
from datetime import datetime 
import pandas as pd 

BASE_PATH = Path().resolve().parent
DF_PATH = BASE_PATH / "data" / "ground_truth_evals" / "product_info.csv"
BASE_PRODÇUCT_URL = "https://tienda.mercadona.es/product/"

# %%
df = pd.read_csv(DF_PATH, sep=";", decimal=",", na_values="-", keep_default_na=False)
df.head()
# Out:
#    ID_producto         marca precio_relativo  \
# 0        22966     Hacendado          barato
# 1         9210     Kellogg's            caro
# 2         4241     Hacendado   caro|muy caro
# 3        21756  Campo Nature        muy caro
# 4        19958       Antonio   caro|muy caro
#
#                                            alergenos           atributos  \
# 0  cereales, gluten, lactosa, frutos de cascara, ...  sin azucar anadido
# 1                                   cereales, gluten
# 2
# 3                                                              ecologico
# 4                                    mostaza, sesamo     fuente de fibra
#
#    energia_kj  energia_kcal  grasas_g  grasas_saturadas_g  carbohidratos_g  \
# 0        1583           373       1.1                 0.4             82.0
# 1        1604           378       0.9                 0.2             84.0
# 2        3378           822      91.4                12.8              0.0
# 3        1502           365      37.2                 6.5              8.9
# 4          79            19       0.4                 0.1              0.8
#
#    azucar_g  fibra_g  proteina_g  sal_g
# 0       0.9      4.4         6.7    1.0
# 1       8.0      3.0         7.0    1.1
# 2       0.0      NaN         0.0    0.0
# 3       0.5      4.0         1.6    4.0
# 4       0.6      4.2         1.0    1.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_producto         24 non-null     int64
#  1   marca               24 non-null     object
#  2   precio_relativo     24 non-null     object
#  3   alergenos           18 non-null     object
#  4   atributos           9 non-null      object
#  5   energia_kj          24 non-null     int64
#  6   energia_kcal        24 non-null     int64
#  7   grasas_g            24 non-null     float64
#  8   grasas_saturadas_g  24 non-null     float64
#  9   carbohidratos_g     24 non-null     float64
#  10  azucar_g            24 non-null     float64
#  11  fibra_g             24 non-null     object
#  12  proteina_g          24 non-null     float64
#  13  sal_g               24 non-null     float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 2.8+ KB
