# %%
from pathlib import Path 
from datetime import datetime 
import pandas as pd 
import numpy as np 
import math

BASE_PATH = Path().resolve().parent
DF_PATH = BASE_PATH / "data" / "ground_truth_evals" / "product_info.csv"
BASE_PRODÇUCT_URL = "https://tienda.mercadona.es/product/"

# %%
df = pd.read_csv(DF_PATH, sep=";", decimal=",", na_values="-", keep_default_na=False)
df.head()
# Out:
#    ID_producto         marca precio_relativo  \
# 0        22966     Hacendado          barato
# 1         9210     Kellogg's            caro
# 2         4241     Hacendado   caro|muy caro
# 3        21756  Campo Nature        muy caro
# 4        19958       Antonio   caro|muy caro
#
#                                   alergenos           atributos  energia_kj  \
# 0  gluten, lactosa, frutos de cascara, soja  sin azucar anadido        1583
# 1                                    gluten                            1604
# 2                                                                      3378
# 3                                                     ecologico        1502
# 4                 mostaza, sesamo, sulfitos     fuente de fibra          79
#
#    energia_kcal  grasas_g  grasas_saturadas_g  carbohidratos_g  azucar_g  \
# 0           373       1.1                 0.4             82.0       0.9
# 1           378       0.9                 0.2             84.0       8.0
# 2           822      91.4                12.8              0.0       0.0
# 3           365      37.2                 6.5              8.9       0.5
# 4            19       0.4                 0.1              0.8       0.6
#
#    fibra_g  proteina_g  sal_g
# 0      4.4         6.7    1.0
# 1      3.0         7.0    1.1
# 2      NaN         0.0    0.0
# 3      4.0         1.6    4.0
# 4      4.2         1.0    1.2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_producto         24 non-null     int64
#  1   marca               21 non-null     str
#  2   precio_relativo     24 non-null     str
#  3   alergenos           24 non-null     str
#  4   atributos           24 non-null     str
#  5   energia_kj          24 non-null     int64
#  6   energia_kcal        24 non-null     int64
#  7   grasas_g            24 non-null     float64
#  8   grasas_saturadas_g  24 non-null     float64
#  9   carbohidratos_g     24 non-null     float64
#  10  azucar_g            24 non-null     float64
#  11  fibra_g             11 non-null     float64
#  12  proteina_g          24 non-null     float64
#  13  sal_g               24 non-null     float64
# dtypes: float64(7), int64(3), str(4)
# memory usage: 2.8 KB

# %%
df.iloc[2].to_dict()["fibra_g"]
# Out:
# nan

# %%
type(df.iloc[13].to_dict()["marca"])
# Out:
# float

# %%
# df.iloc[13]
# Out:
# ID_producto                                            14431
# marca                                                    NaN
# precio_relativo                                    estandar
# alergenos             gluten, lactosa, soja, sesamo, mostaza
# atributos
# energia_kj                                              1121
# energia_kcal                                             265
# grasas_g                                                 3.5
# grasas_saturadas_g                                       1.4
# carbohidratos_g                                         48.0
# azucar_g                                                 6.0
# fibra_g                                                  3.5
# proteina_g                                               8.4
# sal_g                                                    1.2
# Name: 13, dtype: object
